# %% [markdown]
# ## Introduction
# ####  Top Skills of DS ( Data Scientists) on GlassDoor and Indeed
# This program aims at presenting the top 10 skills of DS listed in job descriptions of glassdoor and indeed. For the detail background, deliverables and processes, please see the readme in this git.

# %%
### Load required libraries

# %%
from __future__ import print_function
import pandas as pd
import numpy as np

# Text preprocessing
import os,re
from bs4 import BeautifulSoup
from langdetect import detect

# Disable warning of 3 types
import warnings

#Plotting
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# Other utils
from tqdm import tqdm  # Progress bar

# Azure text analytics service api
#from azure.core.credentials import AzureKeyCredential
#from azure.ai.textanalytics import TextAnalyticsClient

# aws comprehend
import boto3
import json

# %% [markdown]
# ### Pre-settings

# %%
# Set the width to show the column as much as possible.
pd.set_option('display.max_colwidth', 200)

# Disable 3 types of warning
warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore",category=(FutureWarning))
warnings.filterwarnings("ignore",category=(RuntimeWarning))

np.random.seed(1337)

# %% [markdown]
# ### Pipeline of data cleansing
#     - Select the jobs of data scientists.
#     - Remove the duplicated records.
#     - Convert job description in HTML to text.
#     - Store the cleaned data into main table.

# %%
outputfile= './01_data/output/datajobs.csv'
datafile='./01_data/input/glassdoor/glassdoor.csv'
countryfile='./01_data/input/glassdoor/country_names_2_digit_codes.csv'


if os.path.exists(datafile):
    if os.path.exists(outputfile):
        Reload=input("The processed data exist, do you want to reload it?(y/n)")
    else:
        Reload='y'
        
    # reload the data file, and re-produce the csv of data scientist
    if Reload.lower()=='y':
        try:
            glassdoor=pd.read_csv(datafile)
            print("Shape of source file:", glassdoor.shape)
             # Produce the list of jobs related to data
            # Only keep the non-duplicated records by employer names and jobs.
            # Only keep the first records if there are duplicated. Here I keep the latest one
            # Sort the jobs by posted date ascendingly
            data_jobs=glassdoor[glassdoor['header.jobTitle'].str.contains(' data ',case=False)].sort_values(
                by='header.posted',ascending=False).loc[:,[
                'gaTrackerData.industry',
                'header.employerName',
                'gaTrackerData.jobTitle',
                'job.description',
                'header.posted',
                'map.country']]
            # Keep the first record if the duplicated exist.
            data_jobs['duplicated']=data_jobs.duplicated()
            data_jobs_unique=data_jobs[data_jobs['duplicated']==False].loc[:,[
                'gaTrackerData.industry',
                'header.employerName',
                'gaTrackerData.jobTitle',
                'job.description',
                'header.posted',
                'map.country'
            ]]
            data_jobs_unique.to_csv('./01_Data/Output/datajobs.csv')
            print("Shape of jobs related to data:", data_jobs_unique.shape)
            # Assign id into each posted position for the coming identification
            data_jobs_unique['position_id']=data_jobs_unique.index
            # Remove all html tag, and convert each requirements into one item for every posted position.
            jobs = pd.DataFrame(
                columns=[
                    'posting_date',
                    'description',
                    'title',
                    'employer',
                    'industry',
                    'id',
                    'source']
            )
            #for i in tqdm(range(len(data_jobs_unique))):
            for i in range(len(data_jobs_unique)):
                html_page=data_jobs_unique.iloc[i,3]
                soup = BeautifulSoup(html_page, 'html.parser')
                jobs_list = soup.find_all("li")
                job_text=''
                for job in jobs_list:
                    try:
                        lang = detect(str(job.contents[0]))
                    except:
                        lang = "error"
                # Only handle the position described in English 
                # since this program is solely focusing on English 
                    if lang=='en':
                        job_text=job_text + str(job.contents[0]).lower().split("\r\n")[0]+'.'
 
                # Create df to store the converted job description in text format.
                if job_text!='':
                    jobs=jobs.append(
                        {
                            "posting_date":data_jobs_unique.iloc[i,4],
                            "description":job_text,
                            "title":data_jobs_unique.iloc[i,2],
                            "country":data_jobs_unique.iloc[i,5],
                            "employer":data_jobs_unique.iloc[i,1],
                            "industry":data_jobs_unique.iloc[i,0],
                            "id":data_jobs_unique.iloc[i,6],
                            "source":"Glassdoor"
                        },
                                      ignore_index=True) 
                
            jobs.to_csv(outputfile)
        except:
            print("Failed to read the data file, please check the file or path!")
    else:
        jobs=pd.read_csv(outputfile)
# Out:
# Shape of source file: (165290, 163)
# Shape of Data Scientists Jobs: (7289, 6)
# Failed to read the data file, please check the file or path!

# %%
jobs[jobs['title'].str.contains(r'^(?=.*data)(?=.*scientist)',case=False)]['title'].unique()
# Out:
# array(['Young Professional Consultant (w/m/d) Analytics / Data Scientist',
#        'AI/ML Data Scientist', 'Senior Data Scientist',
#        'Junior Data Scientist', 'Delivery Data Scientist',
#        'Lead Data Scientist', 'Statistician/ Data Scientist',
#        'Senior Data Scientist ASME IL Data Science Group',
#        'Lead Research Data Scientist, Oncology R&D, Knowledge Graph team',
#        'Stage - 6 mois - Data Scientist Translation H/F - Paris',
#        'Senior Data Scientist (Marketplace/Machine Learning)',
#        'Research Fellow - Data Scientist',
#        'Senior Professional Data Scientist',
#        'Senior Data Scientist / Advanced Data Analyst',
#        'Manager- Data Scientist',
#        'UniCredit Services SCpA / UniCredit Services SCpA - Area Data & Analytics – Data Scientist',
#        'Stage - 6 mois - Data Scientist NLP & Exploitation de connaissances H/F - Paris',
#        'Senior Data Scientist - [39 Hours]',
#        'Intelligence Data Scientist/Developer',
#        'Data Scientist - Strategic Data Solution',
#        'Research Data Scientist', 'Principal Data Scientist',
#        'Jr. Data Scientist/Data Analyst (Remote - UK Based only)',
#        'Network Data Scientist',
#        'Financial Data Scientist, Refinitiv Labs',
#        'Senior Data Scientist (M/F)', 'Senior Associate Data Scientist',
#        'Senior Data Scientist - Marketing & Growth',
#        'Natural Language Processing Data Scientist',
#        'Senior Data Scientist (Travel・Dialogue Technology)：LLTAD',
#        'Senior Manager, Data Scientist', 'Senior Data Scientists',
#        'STAGE Data scientist',
#        'Semantics Research Scientist (Senior Data Scientist)',
#        'Big Data Scientist / Big Data Engineer (w/m/d)',
#        '(Senior) Data Scientist / Machine Learning Expert (m/w/d) im Bereich FinTech',
#        'Data Miners / Data Scientists', 'Trainee Data Scientist',
#        'Big Data Scientist (NLP)', 'Manager, Data Scientist (Audit)',
#        'Associate Data Scientist', 'Digital Customer IT Data Scientist',
#        'Lead Data Scientist - R&D', 'CIEL/SEL/1942: Jr data scientist',
#        'Staff Data Scientist',
#        'IT Data Scientist Intern - INTERNSHIP/STAGE',
#        'Principal Data Scientist -NLP',
#        'Senior Data Scientist / Machine Learning Engineer (H/F)',
#        'Principal Applied Data Scientist - Machine Learning',
#        'Senior Data Scientist למעבדת חדשנות בעולם ה- Big Data',
#        'Senior Data Scientist - Waterloo (Multiple Roles)',
#        'Senior data / analytics Scientist',
#        'Senior Data Scientist (m/f/d)', 'Fraud Data Scientist',
#        'Sr. Data Scientist', 'Junior Data Scientist - VP 10.19',
#        'Watson Health Data Scientist, NLP / Image Processing',
#        'Product Data Scientist',
#        'Junior Data scientist / Planning Process Expert, Fulltime',
#        'Senior Data Scientist – Machine Learning',
#        'Applied Intelligence Big Data Scientist',
#        'Statistical Data Scientist', 'SUBGERENTE DATA SCIENTIST',
#        'Data Science Digital Pathology Data Sourcing & Integration Scientist',
#        'STAGE - Consultant Data Scientist',
#        'Senior Data Scientist/Data Science Manager',
#        'Young Professional Data Scientist Prognoseverfahren (m/w/d)',
#        'Senior Data Scientist, GameTune',
#        'Product Data Scientist - Healthcheck',
#        'Senior Computer Vision Data Scientist/Engineer',
#        'Senior Data Scientist - Natural Language Processing',
#        'DOCTEUR DATA SCIENTIST H/F', 'Sr Data Scientist',
#        'Senior Data Scientist (Quebec',
#        '(Senior) Real World Data Scientist-Epidemiologist, Neuroscience',
#        'Junior Data Scientist (m/f/d)',
#        'Senior Data Integration Scientist',
#        '(Senior) Data Scientist - Marketplace',
#        '(Senior) Data Scientist (m/f/x)',
#        'Senior Manager - Data Scientist, Advisory, Performance Improvement',
#        'Sr Data Scientist(Machine Learning, Computer Vision, NLP) - India Innovatio POD',
#        'Senior Data Scientist/Machine Learning Engineer (Transport)',
#        'Data Scientist / Senior Data Scientist',
#        'Machine Learning & Data Scientist, Alexa Shopping',
#        'Digital Data Scientist and Analyst',
#        'AI Data Scientist Sr. Manager', 'Senior Data Scientist (Food)',
#        'Data Scientist / Data Engineer',
#        'Manager - Data Scientist, Advisory, Performance Improvement',
#        'Senior Data Scientist (m/f/x)', 'Senior data scientist',
#        'Senior Data Scientist - Product Intelligence',
#        'Geoscientist with Data Science competence',
#        'Werkstudent als Data Scientist im Data & Analytics Competence Center (w/m/d)',
#        'S&OP Data SCIENTIST H/F', 'Data Scientist - Data Platform',
#        'Associate/Senior Associate - Data Scientist, Advisory, Performance Improvement',
#        'Junior Data scientist / Planning Process Expert',
#        'Environmental Data Managers/Data Scientists Consultant (Associate Level)',
#        'Applied Data Scientist', 'Student Intern - Data Scientist',
#        'Chief Data Scientist - ML/AI',
#        'Senior Data Scientist – Front End and Personalization',
#        'Lead Data Scientist - NLP',
#        'Analytics Accelerator - 2 Data Scientists (m/f)',
#        'Lead Data Scientist (m/w/d)',
#        'Senior Analyst/Data Scientist Enterprise Data Governance Remote',
#        'Global Tax Automation & Operations | Data Scientist',
#        'Senior Data Scientist, NLP',
#        'Data Scientist, Enterprise Data Analytics',
#        'Stage - Data Analyst Scientist (H/F) - Janvier',
#        'Senior Machine Learning Data Scientist',
#        'TA/SCS - Data Scientist Staff for Customer Services Business Analytics at Mitsubishi Fuso',
#        'Junior Data Scientist (Big deal pricing, Americas)',
#        'Machine Learning Data Scientist',
#        'Senior Consultant - Data Scientist and Senior Economist',
#        '(Senior) Data Scientist', 'Experienced Data Scientist',
#        'Senior Data Scientist (w/m/d)', 'Biomedical Data Scientist',
#        'Internship - Data Scientist',
#        'Stage - 6 mois - Data Scientist - Deep Learning For Finance H/F - Paris',
#        'Principal Imaging Data Scientist',
#        'IBM Research Scientist Data Scientist',
#        'Lead Data Scientist - Ranks', 'Solution Data Scientist',
#        'Senior Data Scientist - QuantumBlack',
#        'Senior Data Scientist - Natural Language Processing (NLP)',
#        'HR Data Scientist M/F - VIE', 'Field Data Scientist (Singapore)',
#        'Senior Data Scientist-Alexa Shopping Haifa',
#        'Lead Data Scientist - SumUp Bank',
#        'Senior Data Scientist | ML Engineer',
#        'Customer Facing Data Scientist',
#        'Senior R&D Data Scientist (f/m/d)',
#        'Data Analist / Data Scientist', 'Intern (Junior data Scientist)',
#        'Finance Engineering- Corporate Treasury Data Scientist - Analyst',
#        'Systems Engineer - Data Scientist',
#        'Senior Data Scientist Recommendations (f/m/d)',
#        'Bioinformatician/ Data Scientist',
#        'Sr Data Scientist - Food & Bev Strategic Initiatives',
#        'Senior Machine Learning/Deep Learning Data Scientist, RAPIDS - AI',
#        'Senior Data Scientist - Alexa Shopping',
#        'Senior Data Scientist/ Data Scientist/ Data Analyst',
#        'Senior Data Scientist (m/w/d)', 'Consultant- Data Scientist',
#        'Financial Data Scientist', 'Senior NLP Data Scientist',
#        'Senior Data Scientist - Risk',
#        'Experienced Data Scientist – Digital Transformation',
#        'Senior Applied Data Scientist',
#        'Business Data Scientist - AdTech', 'Sr. Manager, Data Scientist',
#        'Sr. IoT Data Scientist - AWS Professional Services',
#        'CDI - Data Scientist (H/F)', 'Digital Data Scientist',
#        'Senior Data Scientist - Search & Discovery',
#        'Commercial Data Scientist - Europe (m/f/d)',
#        'Senior Scientist Deep Data Analytics M/F - Chilly-Mazarin',
#        'LAN PR Data Scientist (ML)',
#        '(Senior) Data Scientist (m/f/x) - Innovation Center / AI Product',
#        'Senior Data Scientist - Machine Learning - ZMS',
#        'Jr. Data Scientist', 'Scientific Research Data Scientist R&D',
#        'Intern Data Scientist - Python',
#        'Principal Data Scientist- Fintech Firm',
#        'Senior Lead / Lead Data Scientist',
#        'Senior Data Scientist, Advanced Analytics',
#        'Senior Data Scientist, Marketplace', 'Chief Data Scientist',
#        'Sr. Data Scientist - Client Platform',
#        'Research Data Scientist- Alexa ML',
#        '(Senior) Data Scientist (m/f/d)',
#        'Senior Data Scientist/ Machine Learning Research Engineer',
#        'Senior Data Scientist - Risk Strategy and Optimisation',
#        'Gamma Lead Data Scientist', 'NLP Data Scientist',
#        'Environmental Data Scientist',
#        'Data Analyst / Data Scientist with Tableau',
#        'OFFRE DE STAGE (H/F) : MACHINE LEARNING - DATA SCIENTIST',
#        'Global Data Scientist', 'Senior Data Scientist / Fintech',
#        'Sr Data Scientist - Fraud', 'Marketing Data Scientist',
#        'Senior Data Scientist - IoT', 'Visiting Associate Data Scientist',
#        'Sr Data Scientist - DNA', 'Consultant Data Scientist',
#        'Gamma Data Scientist', 'Working student - Data Scientist',
#        'Actuarial Data Scientist (m/f/d) in Group Actuarial Planning',
#        'Avionics Engineer - Signal Processing and Data Scientist',
#        'Team Lead - Data Scientist (NLP)',
#        'Cheminformatics Data Scientist',
#        'System Analyst / Data Scientist (Oracle DB, PL SQL, Python, Big Data, Cloud Data Warehouse)',
#        'Sr Data Scientist - Statistical Modeling', 'Jr Data Scientist',
#        'Stage - Data Scientist',
#        'Research Team Lead - PR Data Scientist team',
#        'Principal Sales Consultant - Data Scientist',
#        'Senior Data Scientist , NLP - Gaming', 'Chief data scientist',
#        'BUSINESS INTELLIGENCE DATA SCIENTIST F/H',
#        'Sr. Data Scientist (Bioinformatics)',
#        'Senior Data Scientist, Machine Learning',
#        '【R&D】クリニカルデータサイエンティスト（専門管理職/一般社員）／データモニタリング・マネジメントグループ / Clinical Data Scientist (Exempt/Non-exempt)/Data Monitoring & Management Group',
#        'STAGIAIRE DATA SCIENTIST H/F',
#        'Associate Data Scientist/Data Scientist',
#        'Lead Software Engineer - Data Scientist',
#        "Senior Data Scientist - '", 'Senior Data & Applied Scientist',
#        'Oliver Wyman - Supply Chain Data Scientist',
#        'Senior data scientist (Montreal)',
#        'Senior Data Engineer/Scientist',
#        'CDI - Data Scientist (F/H) : Sephora SAS Siège Neuilly -',
#        'Senior Data Scientist - Growth (f/m/d)',
#        'Computational Data Scientist',
#        'Senior Data Scientist - Personalized Marketing',
#        'RADICALI - Data Scientist',
#        'Machine Learning Engineer / Data Scientist',
#        'Senior Data Scientist - Global AI Accelerator',
#        'Senior Data Scientist - Power&Utilities',
#        'PortCast - Data Scientist',
#        'Analyst, Data Scientist - Retail Banking and Wealth Management',
#        'Data Scientist / Postdoctoral Research Fellow: Data Analytics',
#        'Mid-level Data Scientist (SQL, Python, Spark)',
#        'Senior/Staff Data Scientist - Marketing',
#        'Senior Applied Data Scientist - Machine Learning',
#        'Senior Data Scientist - Advanced Analytics',
#        'Data Scientist/ Data Analyst',
#        'Senior Data Scientist - Commercial',
#        'Middle Data Scientist for Ciklum Solutions Team',
#        'Senior Data Analyst/Data Scientist',
#        'Senior Data Scientist - Data Product',
#        'Advisory – Technology Advisory, Financial Services – Data Scientist',
#        'Principal Data Scientist - LifeLock + Norton',
#        'Data Scientist, Text and Data Mining',
#        '(Senior) Principal Data Scientist, PHC Analytics (Methodology Focus)',
#        'Senior Data Scientist, Tech - Safety',
#        'IBM Internship: Data Scientist Intern',
#        'Principal Knowledge Graph Data Scientist',
#        'AI Palette - Lead NLP Data Scientist',
#        'Ingénieur Data Scientist Junior H/F - Toulouse - CS',
#        'Senior Research Data Scientist', 'Social Data Scientist',
#        'Senior Principal, Data Scientist - Digital',
#        'Junior Data Scientist (full-time)', 'Erfaren Data Scientist',
#        'Machine Learning/ AI Data Scientist Lead',
#        'Senior Data Scientist לסטארטאפ בתחום הרפואי',
#        'Senior Data Scientist Product (m/f/d)',
#        'Data Scientist – Data Analyst',
#        'Quant Data Scientist - UK Contract - Horse Racing Modelling',
#        'Principal Data Scientist, People Analytics',
#        'Portcast: Data Scientist',
#        'Stage : Data Scientist / Engineer H/F (Stage)',
#        'Sustainability Data Scientist',
#        'Credit Risk Data Scientist, Fin Tech',
#        'Senior Data Scientist (m/f/d) for Procurement',
#        'Product Analytics / Data Scientist',
#        'Data Analyst / Data Scientist',
#        'Senior Data Scientist - Computer Vision',
#        'Manager, NLP Data Scientist/Specialist, Data Science, Analytics and Modelling, Audit & Assurance',
#        'GAN Expert - Research Data Scientist (Yepic AI)',
#        'VP, Lead Data Scientist, Data Science Practice',
#        'Core Investment - Data Scientist (Econometrics and Investment Signals)',
#        'Applied AI Data Scientist', 'RTB Data Scientist Intern',
#        'Senior Data Scientist / Engineer',
#        'Senior Data Scientist - Customer Care Technology',
#        'Senior Data Scientist - Operations Strategy',
#        'Operational Excellence - Data Scientist',
#        'Data Analyst / Data Scientist | Internship | Tech-Savvy|',
#        'Senior Data Scientist (m/f) |',
#        'Senior Data Scientist - Commercial Banking',
#        'Senior Data Scientist, Product Analytics',
#        'Sr Network Data Scientist', 'Senior/ Lead Data Scientist',
#        'Junior Energy Data Scientist',
#        'Senior Data Scientist - Hang Seng Bank (HK)',
#        'Senior Data Scientist & Project Manager',
#        'Senior Data Scientist - IMMEDIATE',
#        'IT Software - Data Scientist/Analyst Engineer',
#        'Junior Data Scientist 3 month Contract',
#        'Senior Data Scientist / Senior Data Engineer',
#        'Senior Data Scientist - Experimentation, Payments',
#        'Advisor, Technical Data Scientist, FCM',
#        '【New】Senior Data Scientist',
#        'Senior Data Scientist - AWS Professional Services',
#        'Senior Data Scientist, Business Analytics',
#        'Evidence Generation Data Scientist or Sr Associate, Data Scientist / Epidemiologist',
#        'Manager, Data Scientist (2 year contract)',
#        'Lead Data Scientist - Southampton - £69,350 p.a.',
#        'INTERNATIONAL PROGRAMME FOR JUNIORS (VIE) - GEOSCIENCE DATA SCIENTIST (M/F)',
#        'Data Scientist / Software Engineer Data Science (f/m/d)',
#        'Statistician - Data Scientist', 'Sr.Analyst / Data Scientist',
#        'REPLY - Experienced Data Scientist',
#        'Senior Data Scientist (multiple roles)',
#        'Senior Specialist- Data Integration Scientist',
#        'Data Scientist / Data Engineer (d/m/f)',
#        'Senior Data Scientist (m/f) | Hamburg',
#        'Data Scientists with real world data experience for Data Analytics department',
#        'IS/IT Data Scientist Specialist (ASL)',
#        'WINTER INTERN: Data Scientist',
#        'Senior Data Scientist, Algorithms (d/f/m)',
#        'Senior Data Scientist - NLP',
#        'Data Analyst / Data Scientist - Marketing',
#        'Junior Data Scientist/Teaching Assistant - - eLearning 1-5Yrs',
#        'Data Scientist / Data Engineer (m/f/diverse) - limited for one year',
#        'Data Scientist/Senior Data Scientist, Real World Data Collaborations, Personalized Healthcare (PHC)',
#        'Senior Data Scientist, Growth',
#        'Lead Data Scientist - Center of Excellence for Data and Analytics',
#        'Scientist Data Science (m/f/d)',
#        'Principal/Sr. Principal Data Scientist, Real World Data, Personalized Healthcare (PHC)',
#        'Product Controller & Data Scientist',
#        'Big Data Engineer / Scientist (m/w)',
#        'Transport Data Scientist (m/f/d)',
#        'Senior Data Scientist Consultant', 'Senior / Lead Data Scientist',
#        'Data Scientist / Data Analyst - CK',
#        'Data Scientists for programming and data management of real-world data in Data Analytics department',
#        '3M HIS Advanced Data Scientist (Murray, UT / St. Paul, MN/Pittsburgh, PA)',
#        'Sr. NLP Data Scientist',
#        'Lead Data Scientist - Merch Pricing/Promotions',
#        'Assistant Vice President - Data Scientist - Data Engineer',
#        'Senior Data Scientist - Dynamic Pricing',
#        'Big Data Junior Scientist', 'Manager, Clinical Data Scientist',
#        'Senior Data Scientist - Platform & Partner Experiences',
#        'MASTER DATA SCIENTIST', 'Sr. Data Scientist Analytics',
#        'Quantitative Analyst Data Scientist - Dynamic Markets - AMP Capital',
#        'Senior Data Scientist - Claims Analytics Centre of Excellence',
#        '(Senior) Data Scientist / Statistician Digitalisation/ Industry 4.0 (m/f/d) - Datenbankentwicklung / BI, IT',
#        'Associate Scientist / Scientist Data Science, Oncology Biomarker Development',
#        'Senior Bio-Informatics and Data Mining Scientist of the Target Incubator Unit (f/m/d)',
#        'Senior Data Scientist, Predictive Modeling', 'Mid Data Scientist',
#        'Senior LiDAR Data Scientist', 'Junior PhD Data Scientists',
#        'Computer Scientist - Data Engineering',
#        'Senior Data Scientist Search (m/f/d)', '(Junior) Data Scientist',
#        'Data Scientist / Data Warehouse Development Specialist',
#        'Senior Applied Data Scientist (f/m/x) BMW AG',
#        'Lead Data Scientist / IA / Freelance',
#        'Fall 2020 - Mathematician, Cryptanalyst and Data Scientist',
#        'Scientist - Business Data Services',
#        'Data Scientist voor data gedreven klantoplossingen',
#        'Data Scientist – Pricing, Data & Analytics, Group Digital',
#        '(Senior) Data Scientist (m/f/d) – Forecasting & Credit Risk',
#        'Quant Researcher / Data Scientist for High Frequency Trading at Hedge Fund',
#        'SECURITY DATA SCIENTIST',
#        'Senior Data Scientist - Machine Learning',
#        'Gedreven Data Scientist met gedegen werkervaring!',
#        'Lead Data Scientist (NLP)',
#        'KGS MC | Data & Analytics | Data Scientist',
#        'Senior Data Scientist, Marketing Insights & Analytics,VP',
#        'Senior Data Scientist - Predictive Enterprise Group',
#        'Senior Data Scientist/Engineer',
#        'Senior Data Scientist, Operations',
#        'Senior Data Scientist / Machine Learning Engineer Cape Town',
#        'BI Data Scientist (6 Months contract)',
#        'Senior Applied Data Scientist (f/m/x)',
#        'Energy Modeling Data Scientist',
#        'Manager (f/m/d) Data Scientist with SAP background - Assurance Digital Center',
#        'Senior Data Scientist (FT)',
#        'Senior (f/m/d) Data Scientist with SAP background - Assurance Digital Center',
#        'Principal Data Scientist (USBU)',
#        'Senior Data Scientist / Backend Engineer',
#        'Senior Data Scientist - Forensics', 'Microsoft Data Scientist',
#        'Senior Data Decision Scientist - Marketing',
#        'Sr. Data Scientist – R, Python, Machine Learning',
#        'Senior Data Scientist / Machine Learning Engineer',
#        'Intern Data Scientist (m/f/d)', 'Intern, Data Scientist',
#        '(Senior) Data Scientist - Central Data Science',
#        'Insurance Data Scientist',
#        'Senior Data Scientist, AI & Unstructured data',
#        'Data Scientist - Data Modelling - Customer Analytics',
#        'Associate/Senior Associate - Data Scientist, Investment Analytics and Insights',
#        'Senior Data Scientist - marketing sciences training available!',
#        'Junior Data Scientist - R&D Data Lab',
#        'Senior Data Scientist - customer analytics',
#        'Robotic Process Automation Data Scientist',
#        'Senior Data Scientist - Search Platform',
#        'Senior Data Scientist - Modeling',
#        '(Senior) Data Scientist (m/f/x) - Datenbankentwicklung / BI, IT',
#        'Young Professional Consultant (w/m/d) Analytics / Data Scientist - Datenbankentwicklung / BI, IT',
#        'Customer Analytics - (Senior) Data Analyst/ Strategic Data Scientist',
#        'Imaging Biometrics & Identity Intelligence Data Scientist',
#        'Senior Data Scientist - Procurement Team',
#        'Walkin interview IT Data Scientist',
#        "Delegates (Queen's Women in Leadership) - Data Scientist, Summer Intern/Co-op",
#        'Innovation Expert - Data Scientist', 'Language Data Scientist',
#        'Lead AI Data Scientist',
#        'Paid internship in Information Technology - Data Scientist -Switzerland, 6 months (m/f)',
#        'Senior Social Data Scientist',
#        '(Senior) Data Scientist / Statistician Digitalisation/ Industry 4.0 (m/f/d)',
#        'Team Lead - Data Scientist',
#        'Data Engineer / Data Scientist - Python / Flask / AWS',
#        'Senior / Principal Data Scientist, PHC Analytics',
#        'Machine Learning Developer/ Data Scientist',
#        'Freelance Data Scientist - Python/R/ML',
#        'Senior Data Scientist, Business Decisions (d/f/m)',
#        'Director, Data Scientist - Match, Entity Resolution',
#        'Supermercato24 - Data Scientist',
#        'Senior Data Scientist - Product Development',
#        'Senior / Lead / Principal Data Scientist, Search',
#        'Deloitte, Data Scientists',
#        'Lead Research Data Scientist-Oncology R&D-Knowledge Graphs',
#        'SENIOR DATA SCIENTIST (HUB DE DATA)',
#        'Sr. Data Scientist - Experimentation',
#        'Principal Data Scientist Innovation',
#        'Senior Data Scientist - Customer Aligned',
#        'Biomarker Data Scientist (m/f/d)', 'jr Data Scientist',
#        'Senior Data Analyst / Scientist',
#        'Contract Principle Architect / Data Scientist',
#        'Stage : Stage - 6 mois - Data Scientist - Deep Learning For Finance H/F - Paris',
#        'Junior Data scientist', 'A/M/SM - Data Scientist-BFSI',
#        'Senior Data Scientist - NLP & Knowledge Graphs',
#        'Research Data Scientists', 'Senior Data Scientist (AWS)',
#        'Senior Data Scientist (TEL AVIV!) - Cloud App Security',
#        'Sr. Data Scientist/Data Scientist II-- O365 Connectivity',
#        'INTERN - Data Scientist (m/w/d)',
#        'Principal Applied Data Scientist',
#        'Principal Applied Data Scientist Manager',
#        'Mitarbeiter Data Scientist (w/m/d)',
#        'D/ASE/DATASCIENTIST - Ingénieur Data Scientist Expérimenté H/F',
#        'Stage : Assistant Data Scientist - Moteur de recherche sémantique H/F'],
#       dtype=object)

# %%
# To do list:
# Fill the country.
#country_df=pd.read_csv(countryfile)

# Fill the industry

#Pickup the jobs of data scientists
df_main=jobs[jobs['title'].str.contains(r'^(?=.*data)(?=.*scientist)',case=False)]
df_main
# Out:
#       posting_date  \
# 2      Sep 5, 2019
# 5     Sep 27, 2019
# 12    Sep 23, 2019
# 17    Sep 19, 2019
# 18    Sep 18, 2019
# ...            ...
# 3275   Aug 9, 2019
# 3276   Aug 9, 2019
# 3290  Aug 23, 2019
# 3291  Aug 21, 2019
# 3292  Aug 21, 2019
#
#                                                                                                                                                                                                   description  \
# 2                                                                                                                                                                interesse an innovativen technologie-themen.
# 5     *artificial intelligence/ machine learning data scientist**.*main duties and responsibilities of the job**.investigating the stateoftheart methods in nlp, machine learning and ai.applying nlp meth...
# 12    demonstrable handson experience in deploying and maintaining machine learning models in production environments.familiar with offline (batch) and online (live/stream) data pipelines.advanced pytho...
# 17    performing fundamental research work on applying deep learning to different types of data (categorical, temporal, etc.)..constructing data pipelines and applying data processing, cleansing and int...
# 18    experience with at least one of the ml related technologies (azure ml, mllib, h20, scikit-learn, various r packages).hands on experience with either r or python for both data prep and modeling.dem...
# ...                                                                                                                                                                                                       ...
# 3275  ms/bs in cs/ee, mathematical or machine learning related disciplines, with 10 or more years of experience.solid understanding ofprobability, statistics, machine learning, data science.a/b testing ...
# 3276  ms/bs in cs/ee, mathematical or machine learning related disciplines, with 10 or more years of experience.experience leading a team of applied data scientists.solid understanding ofprobability, st...
# 3290                                                                                                                                                                                         agiler workflow.
# 3291                                                             algorithmes de data mining.algorithmes de machine learning supervisés ou non tels que decision tree, random forest, svm, neural network ....
# 3292                                                                                                          machine learning et deep learning.plateformes de recherche d'information : elasticsearch, solr.
#
#                                                                       title  \
# 2          Young Professional Consultant (w/m/d) Analytics / Data Scientist
# 5                                                      AI/ML Data Scientist
# 12                                                    Senior Data Scientist
# 17                                                    Junior Data Scientist
# 18                                                  Delivery Data Scientist
# ...                                                                     ...
# 3275                                       Principal Applied Data Scientist
# 3276                               Principal Applied Data Scientist Manager
# 3290                                     Mitarbeiter Data Scientist (w/m/d)
# 3291         D/ASE/DATASCIENTIST - Ingénieur Data Scientist Expérimenté H/F
# 3292  Stage : Assistant Data Scientist - Moteur de recherche sémantique H/F
#
#                       employer                               industry      id  \
# 2           Camelot ITLab GmbH                             Consulting  152120
# 5                 Tec Partners                                    NaN   39596
# 12              Wade Macdonald                 Staffing & Outsourcing  110208
# 17                      Giatec  Electrical & Electronic Manufacturing   30157
# 18                   Microsoft           Computer Hardware & Software  127407
# ...                        ...                                    ...     ...
# 3275                 Microsoft           Computer Hardware & Software  118265
# 3276                 Microsoft           Computer Hardware & Software   15064
# 3290  eClever Entwicklungs OHG                                    NaN   97849
# 3291                Groupe SII                            IT Services  126961
# 3292           Crédit Agricole  Investment Banking & Asset Management  164650
#
#          source         country
# 2     Glassdoor             NaN
# 5     Glassdoor  United Kingdom
# 12    Glassdoor  United Kingdom
# 17    Glassdoor          Canada
# 18    Glassdoor           India
# ...         ...             ...
# 3275  Glassdoor           India
# 3276  Glassdoor           India
# 3290  Glassdoor              DE
# 3291  Glassdoor          France
# 3292  Glassdoor          France
#
# [769 rows x 8 columns]

# %% [markdown]
# ### Extract skills from AWS

# %%
sample_frac=1 # % of total records for sample processing.
cf_score=0.8  # confidence score threshold for key phrases

# Call AWS comprehend to extract key phrases

comprehend = boto3.client(service_name='comprehend', region_name='us-east-2')
                
#text = "It is raining today in Seattle"

print('Calling DetectKeyPhrases')
#df=pd.DataFrame()
df_list=[]

for i in range(round(sample_frac*len(main_df))):
    if len(main_df["description"].iloc[i])<=5000: #AWS' limitation on one request
        dump_json=json.dumps(comprehend.detect_key_phrases(Text=main_df["description"].iloc[i]
                                                       , LanguageCode='en'), sort_keys=True, indent=4)
        df_phrases=pd.json_normalize(json.loads(dump_json)['KeyPhrases'])
        df_phrases['id']=main_df["id"].iloc[i]
        df_list.append(df_phrases)

    else:
        None # to be handled
        
df=pd.concat(df_list)
print('End of DetectKeyPhrases\n')
# Out:
# Calling DetectKeyPhrases
# End of DetectKeyPhrases

# %%
# Generate the dataframe of skills
df_skills=pd.DataFrame(df[df['Score']>=cf_score][['id','Text']])
df_skills.columns=['id','skill']
df_skills['type']=''

# %%
df_skills.groupby(['skill']).count()[df_skills.groupby(['skill']).count()['id']>20].sort_values('id',ascending=False)
# Out:
#                       id  type
# skill
# experience           402   402
# data                 390   390
# computer science     240   240
# machine learning     227   227
# machine              218   218
# ...                  ...   ...
# tableau               21    21
# predictive modeling   21    21
# hands                 21    21
# <strong               21    21
# development           21    21
#
# [112 rows x 2 columns]
